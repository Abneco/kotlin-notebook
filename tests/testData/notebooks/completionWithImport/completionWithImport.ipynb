// %%
%useLatestDescriptors
%use ggdsl(v=0.2.4-dev-1)

// %%
plot {
    line {
        type(<caret>)
    }
}
// Out:
// Line_7.jupyter.kts (3:9 - 13) Not enough information to infer type variable DomainType
// Line_7.jupyter.kts (3:14 - 15) No value passed for parameter 'data'
